# %% [markdown]
# ## Content:
# ### 01. Import Libraries and Data
# ### 02. Consistency Checks
# ### 03. Data Wrangling
# ### 04. Create New Columns
# ### 05. Export Dataframe

# %% [markdown]
# ## 01. Import Libraries and Data

# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
# define path
path = r'C:\Users\Bilel\Desktop\data_analyst_Carrer Foundry\Data Immersion\A6-Advanced Analytics & Dashboard Design\20-01-24 NY Citi Bike project'

# %%
 # import data

df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'citibike.csv'), index_col = False)

# %%
df.head()
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22               521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 4  2013-09-07 18:46:38             476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  trip_duration      subscriber  \
# 0             40.742388             -73.997262            993      Subscriber
# 1             40.728419             -73.987140            581      Subscriber
# 2             40.768254             -73.988639            361      Subscriber
# 3             40.756014             -73.967416            561      Subscriber
# 4             40.743943             -73.979661           2296  Non-Subscriber
#
#    birth_year  gender
# 0      1968.0       2
# 1      1983.0       1
# 2      1989.0       1
# 3      1988.0       2
# 4         NaN       0

# %%
df.shape
# Out:
# (50000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  50000 non-null  object
#  1   bike_id                  50000 non-null  int64
#  2   weekday                  50000 non-null  object
#  3   start_hour               50000 non-null  int64
#  4   start_time               50000 non-null  object
#  5   start_station_id         50000 non-null  int64
#  6   start_station_name       50000 non-null  object
#  7   start_station_latitude   50000 non-null  float64
#  8   start_station_longitude  50000 non-null  float64
#  9   end_time                 50000 non-null  object
#  10  end_station_id           50000 non-null  int64
#  11  end_station_name         50000 non-null  object
#  12  end_station_latitude     50000 non-null  float64
#  13  end_station_longitude    50000 non-null  float64
#  14  trip_duration            50000 non-null  int64
#  15  subscriber               50000 non-null  object
#  16  birth_year               43021 non-null  float64
#  17  gender                   50000 non-null  int64
# dtypes: float64(5), int64(6), object(7)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#             bike_id    start_hour  start_station_id  start_station_latitude  \
# count  50000.000000  50000.000000      50000.000000            50000.000000
# mean   17615.269360     14.145240        443.321500               40.734170
# std     1675.407446      4.860541        356.559925                0.019911
# min    14556.000000      0.000000         72.000000               40.680342
# 25%    16188.000000     10.000000        304.000000               40.720196
# 50%    17584.000000     15.000000        402.000000               40.735877
# 75%    19014.000000     18.000000        484.000000               40.750020
# max    20642.000000     23.000000       3002.000000               40.770513
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             50000.000000    50000.000000          50000.000000
# mean                -73.991109      442.539700             40.733859
# std                   0.012555      355.756022              0.019885
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.000271      304.000000             40.720196
# 50%                 -73.990765      402.000000             40.735354
# 75%                 -73.981923      483.000000             40.749013
# max                 -73.950048     3002.000000             40.770513
#
#        end_station_longitude  trip_duration    birth_year        gender
# count           50000.000000   50000.000000  43021.000000  50000.000000
# mean              -73.991351     838.982900   1975.627786      1.073540
# std                 0.012569     573.663997     11.089001      0.589389
# min               -74.017134      60.000000   1899.000000      0.000000
# 25%               -74.001547     417.000000   1968.000000      1.000000
# 50%               -73.991218     672.000000   1978.000000      1.000000
# 75%               -73.982050    1112.000000   1984.000000      1.000000
# max               -73.950048    2697.000000   1997.000000      2.000000

# %% [markdown]
# ## 02. Consistency Checks

# %%
# check for mixed-type columns
for col in df.columns.tolist():
    weird = (df[[col]].map(type) != df[[col]].iloc[0].map(type)).any(axis=1)
    if len(df[weird]) > 0:
        print(col)

# %%
# check for missing values
df.isnull().sum()
# Out:
# trip_id                       0
# bike_id                       0
# weekday                       0
# start_hour                    0
# start_time                    0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_time                      0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# trip_duration                 0
# subscriber                    0
# birth_year                 6979
# gender                        0
# dtype: int64

# %%
# create subset of data with missing birth years
df_nan = df[df['birth_year'].isnull() == True]

# %%
df_nan
# Out:
#       trip_id  bike_id weekday  start_hour           start_time  \
# 4      VGBsb5    18024     Sat          18  2013-09-07 18:08:22
# 10     aZsCdK    15732     Sat          20  2013-09-07 20:01:58
# 17     VqhF3S    15651     Mon          18  2013-09-30 18:32:48
# 26     9yZrq6    17506     Sun          16  2013-09-01 16:18:58
# 46     t1KBiF    19206     Sun          22  2013-09-01 22:49:52
# ...       ...      ...     ...         ...                  ...
# 49986  8wDcq8    19293     Sun          22  2013-09-29 22:00:43
# 49988  C0ivmQ    18118     Sun          12  2013-09-22 12:19:44
# 49993  cvgHF4    18458     Wed          19  2013-09-25 19:01:07
# 49995  Fb2bmC    17988     Sat          18  2013-09-21 18:39:20
# 49998  xxacSt    16763     Sat          13  2013-09-07 13:25:35
#
#        start_station_id      start_station_name  start_station_latitude  \
# 4                   521         8 Ave & W 31 St               40.750450
# 10                  457      Broadway & W 58 St               40.766953
# 17                  363          West Thames St               40.708347
# 26                  389     Broadway & Berry St               40.710446
# 46                  426   West St & Chambers St               40.717548
# ...                 ...                     ...                     ...
# 49986               469      Broadway & W 53 St               40.763441
# 49988               352         W 56 St & 6 Ave               40.763406
# 49993               284   Greenwich Ave & 8 Ave               40.739017
# 49995               479         9 Ave & W 45 St               40.760193
# 49998               271  Ashland Pl & Hanson Pl               40.685282
#
#        start_station_longitude             end_time  end_station_id  \
# 4                   -73.994811  2013-09-07 18:46:38             476
# 10                  -73.981693  2013-09-07 20:23:51             512
# 17                  -74.017134  2013-09-30 19:01:59             514
# 26                  -73.965251  2013-09-01 16:26:56             389
# 46                  -74.013221  2013-09-01 23:06:48             247
# ...                        ...                  ...             ...
# 49986               -73.982681  2013-09-29 22:17:52             444
# 49988               -73.977225  2013-09-22 12:29:55             464
# 49993               -74.002638  2013-09-25 19:19:11             329
# 49995               -73.991255  2013-09-21 20:08:59             478
# 49998               -73.978058  2013-09-07 14:14:04             373
#
#                    end_station_name  end_station_latitude  \
# 4                   E 31 St & 3 Ave             40.743943
# 10                  W 29 St & 9 Ave             40.750073
# 17                 12 Ave & W 40 St             40.760875
# 26              Broadway & Berry St             40.710446
# 46           Perry St & Bleecker St             40.735354
# ...                             ...                   ...
# 49986            Broadway & W 24 St             40.742354
# 49988               E 56 St & 3 Ave             40.759345
# 49993     Greenwich St & N Moore St             40.720434
# 49995              11 Ave & W 41 St             40.760301
# 49998  Willoughby Ave & Walworth St             40.693317
#
#        end_station_longitude  trip_duration      subscriber  birth_year  \
# 4                 -73.979661           2296  Non-Subscriber         NaN
# 10                -73.998393           1313  Non-Subscriber         NaN
# 17                -74.002777           1751  Non-Subscriber         NaN
# 26                -73.965251            478  Non-Subscriber         NaN
# 46                -74.004831           1016  Non-Subscriber         NaN
# ...                      ...            ...             ...         ...
# 49986             -73.989151           1029  Non-Subscriber         NaN
# 49988             -73.967597            611  Non-Subscriber         NaN
# 49993             -74.010206           1084  Non-Subscriber         NaN
# 49995             -73.998842           2697  Non-Subscriber         NaN
# 49998             -73.953820           2697  Non-Subscriber         NaN
#
#        gender
# 4           0
# 10          0
# 17          0
# 26          0
# 46          0
# ...       ...
# 49986       0
# 49988       0
# 49993       0
# 49995       0
# 49998       0
#
# [6979 rows x 18 columns]

# %%
# impute median value into missing birth years 
df['birth_year'] = df['birth_year'].fillna(df['birth_year'].median())

# %% [markdown]
# I chose to impute the median instead of mean to try to account for any outliers, and to reduce the risk of skewing the data. I did not want to delete 13.94% of the data and risk further analysis being drastically altered.

# %%
# second check for missing values
df.isnull().sum()
# Out:
# trip_id                    0
# bike_id                    0
# weekday                    0
# start_hour                 0
# start_time                 0
# start_station_id           0
# start_station_name         0
# start_station_latitude     0
# start_station_longitude    0
# end_time                   0
# end_station_id             0
# end_station_name           0
# end_station_latitude       0
# end_station_longitude      0
# trip_duration              0
# subscriber                 0
# birth_year                 0
# gender                     0
# dtype: int64

# %%
# check for duplicates
df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [trip_id, bike_id, weekday, start_hour, start_time, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_time, end_station_id, end_station_name, end_station_latitude, end_station_longitude, trip_duration, subscriber, birth_year, gender]
# Index: []

# %%
df.describe()
# Out:
#             bike_id    start_hour  start_station_id  start_station_latitude  \
# count  50000.000000  50000.000000      50000.000000            50000.000000
# mean   17615.269360     14.145240        443.321500               40.734170
# std     1675.407446      4.860541        356.559925                0.019911
# min    14556.000000      0.000000         72.000000               40.680342
# 25%    16188.000000     10.000000        304.000000               40.720196
# 50%    17584.000000     15.000000        402.000000               40.735877
# 75%    19014.000000     18.000000        484.000000               40.750020
# max    20642.000000     23.000000       3002.000000               40.770513
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             50000.000000    50000.000000          50000.000000
# mean                -73.991109      442.539700             40.733859
# std                   0.012555      355.756022              0.019885
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.000271      304.000000             40.720196
# 50%                 -73.990765      402.000000             40.735354
# 75%                 -73.981923      483.000000             40.749013
# max                 -73.950048     3002.000000             40.770513
#
#        end_station_longitude  trip_duration    birth_year        gender
# count           50000.000000   50000.000000  50000.000000  50000.000000
# mean              -73.991351     838.982900   1975.958900      1.073540
# std                 0.012569     573.663997     10.318811      0.589389
# min               -74.017134      60.000000   1899.000000      0.000000
# 25%               -74.001547     417.000000   1970.000000      1.000000
# 50%               -73.991218     672.000000   1978.000000      1.000000
# 75%               -73.982050    1112.000000   1983.000000      1.000000
# max               -73.950048    2697.000000   1997.000000      2.000000

# %% [markdown]
# In the descriptive stats above, it says that the minimum birth year is 1899, I highly doubt that someone born in 1899 would be renting a bike in 2013. I'm going to check the birth year colun for extreme values.

# %%
# check for birth years prior to 1913

df[df['birth_year'] <1913].shape
# Out:
# (23, 18)

# %% [markdown]
# Since there are less than 30 records with birth years prior to 1913, I will delete them from the dataset. Choosing 1913 was generous, however there are some spry centenarians out there!

# %%
df_new = df[df['birth_year'] > 1913]

# %%
df_new.shape
# Out:
# (49977, 18)

# %%
# making sure there are 7 days of the week
df_new['weekday'].unique()
# Out:
# array(['Mon', 'Thu', 'Wed', 'Sat', 'Fri', 'Sun', 'Tue'], dtype=object)

# %% [markdown]
# ## 03. Data Wrangling

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49977 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  49977 non-null  object
#  1   bike_id                  49977 non-null  int64
#  2   weekday                  49977 non-null  object
#  3   start_hour               49977 non-null  int64
#  4   start_time               49977 non-null  object
#  5   start_station_id         49977 non-null  int64
#  6   start_station_name       49977 non-null  object
#  7   start_station_latitude   49977 non-null  float64
#  8   start_station_longitude  49977 non-null  float64
#  9   end_time                 49977 non-null  object
#  10  end_station_id           49977 non-null  int64
#  11  end_station_name         49977 non-null  object
#  12  end_station_latitude     49977 non-null  float64
#  13  end_station_longitude    49977 non-null  float64
#  14  trip_duration            49977 non-null  int64
#  15  subscriber               49977 non-null  object
#  16  birth_year               49977 non-null  float64
#  17  gender                   49977 non-null  int64
# dtypes: float64(5), int64(6), object(7)
# memory usage: 7.2+ MB

# %%
# convert start_time data type to datetime
df_new['start_time'] = pd.to_datetime(df_new['start_time'])
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\1888154182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['start_time'] = pd.to_datetime(df_new['start_time'])

# %%
# convert end_time data type to datetime

df_new['end_time'] = pd.to_datetime(df_new['end_time'])
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\1207836256.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['end_time'] = pd.to_datetime(df_new['end_time'])

# %%
df_new.dtypes
# Out:
# trip_id                            object
# bike_id                             int64
# weekday                            object
# start_hour                          int64
# start_time                 datetime64[ns]
# start_station_id                    int64
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_time                   datetime64[ns]
# end_station_id                      int64
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# trip_duration                       int64
# subscriber                         object
# birth_year                        float64
# gender                              int64
# dtype: object

# %%
# convert id_columns to object

cols = ['bike_id', 'start_station_id', 'end_station_id', 'gender']
for col in cols:
    df_new[col] = df_new[col].astype('str')
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\3171331996.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[col] = df_new[col].astype('str')
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\3171331996.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[col] = df_new[col].astype('str')
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\3171331996.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[col] = df_new[col].astype('str')
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\3171331996.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new[col] = df_new[col].astype('str')

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49977 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  49977 non-null  object
#  1   bike_id                  49977 non-null  object
#  2   weekday                  49977 non-null  object
#  3   start_hour               49977 non-null  int64
#  4   start_time               49977 non-null  datetime64[ns]
#  5   start_station_id         49977 non-null  object
#  6   start_station_name       49977 non-null  object
#  7   start_station_latitude   49977 non-null  float64
#  8   start_station_longitude  49977 non-null  float64
#  9   end_time                 49977 non-null  datetime64[ns]
#  10  end_station_id           49977 non-null  object
#  11  end_station_name         49977 non-null  object
#  12  end_station_latitude     49977 non-null  float64
#  13  end_station_longitude    49977 non-null  float64
#  14  trip_duration            49977 non-null  int64
#  15  subscriber               49977 non-null  object
#  16  birth_year               49977 non-null  float64
#  17  gender                   49977 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 7.2+ MB

# %%
#changing column name from weekday to day of week
df_new.rename(columns = {'weekday':'day_of_week'}, inplace = True)
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\3142872660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.rename(columns = {'weekday':'day_of_week'}, inplace = True)

# %%
df_new.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber  birth_year gender
# 0            993      Subscriber      1968.0      2
# 1            581      Subscriber      1983.0      1
# 2            361      Subscriber      1989.0      1
# 3            561      Subscriber      1988.0      2
# 4           2296  Non-Subscriber      1978.0      0

# %%
# making sure there are 7 days of the week

df_new['day_of_week'].unique()
# Out:
# array(['Mon', 'Thu', 'Wed', 'Sat', 'Fri', 'Sun', 'Tue'], dtype=object)

# %% [markdown]
# ## 04. Create New Columns

# %%
# create trip_duration_minutes column to convert trip time from seconds to minutes
df_new['trip_duration_minutes'] = df_new['trip_duration'] // 60
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\811549853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['trip_duration_minutes'] = df_new['trip_duration'] // 60

# %%
df_new.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber  birth_year gender  trip_duration_minutes
# 0            993      Subscriber      1968.0      2                     16
# 1            581      Subscriber      1983.0      1                      9
# 2            361      Subscriber      1989.0      1                      6
# 3            561      Subscriber      1988.0      2                      9
# 4           2296  Non-Subscriber      1978.0      0                     38

# %%
# create new column for age of customer
df_new['birth_year'] = df_new['birth_year'].astype(int)
df_new['age'] = (2013 - df_new['birth_year'])
# Out:
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\83724026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['birth_year'] = df_new['birth_year'].astype(int)
# C:\Users\Bilel\AppData\Local\Temp\ipykernel_7664\83724026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['age'] = (2013 - df_new['birth_year'])

# %%
df_new.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber  birth_year gender  trip_duration_minutes  \
# 0            993      Subscriber        1968      2                     16
# 1            581      Subscriber        1983      1                      9
# 2            361      Subscriber        1989      1                      6
# 3            561      Subscriber        1988      2                      9
# 4           2296  Non-Subscriber        1978      0                     38
#
#    age
# 0   45
# 1   30
# 2   24
# 3   25
# 4   35

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49977 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trip_id                  49977 non-null  object
#  1   bike_id                  49977 non-null  object
#  2   day_of_week              49977 non-null  object
#  3   start_hour               49977 non-null  int64
#  4   start_time               49977 non-null  datetime64[ns]
#  5   start_station_id         49977 non-null  object
#  6   start_station_name       49977 non-null  object
#  7   start_station_latitude   49977 non-null  float64
#  8   start_station_longitude  49977 non-null  float64
#  9   end_time                 49977 non-null  datetime64[ns]
#  10  end_station_id           49977 non-null  object
#  11  end_station_name         49977 non-null  object
#  12  end_station_latitude     49977 non-null  float64
#  13  end_station_longitude    49977 non-null  float64
#  14  trip_duration            49977 non-null  int64
#  15  subscriber               49977 non-null  object
#  16  birth_year               49977 non-null  int32
#  17  gender                   49977 non-null  object
#  18  trip_duration_minutes    49977 non-null  int64
#  19  age                      49977 non-null  int32
# dtypes: datetime64[ns](2), float64(4), int32(2), int64(3), object(9)
# memory usage: 7.6+ MB

# %%
df_new.describe()
# Out:
#          start_hour                     start_time  start_station_latitude  \
# count  49977.000000                          49977            49977.000000
# mean      14.146027  2013-09-16 14:32:00.605778688               40.734171
# min        0.000000            2013-09-01 00:00:35               40.680342
# 25%       10.000000            2013-09-09 10:25:48               40.720196
# 50%       15.000000            2013-09-16 18:54:24               40.735877
# 75%       18.000000            2013-09-23 21:56:14               40.750020
# max       23.000000            2013-09-30 23:58:17               40.770513
# std        4.860599                            NaN                0.019911
#
#        start_station_longitude                       end_time  \
# count             49977.000000                          49977
# mean                -73.991106  2013-09-16 14:47:12.717830400
# min                 -74.017134            2013-09-01 00:07:15
# 25%                 -74.000271            2013-09-09 10:41:15
# 50%                 -73.990765            2013-09-16 19:12:12
# 75%                 -73.981923            2013-09-23 22:07:20
# max                 -73.950048            2013-10-01 00:15:29
# std                   0.012552                            NaN
#
#        end_station_latitude  end_station_longitude  trip_duration  \
# count          49977.000000           49977.000000   49977.000000
# mean              40.733861             -73.991348     838.877624
# min               40.680342             -74.017134      60.000000
# 25%               40.720196             -74.001547     417.000000
# 50%               40.735354             -73.991218     672.000000
# 75%               40.749013             -73.982050    1112.000000
# max               40.770513             -73.950048    2697.000000
# std                0.019885               0.012569     573.675762
#
#          birth_year  trip_duration_minutes           age
# count  49977.000000           49977.000000  49977.000000
# mean    1975.993717              13.480821     37.006283
# min     1917.000000               1.000000     16.000000
# 25%     1970.000000               6.000000     30.000000
# 50%     1978.000000              11.000000     35.000000
# 75%     1983.000000              18.000000     43.000000
# max     1997.000000              44.000000     96.000000
# std       10.192610               9.534390     10.192610

# %% [markdown]
# ## 05. Export Dataframe

# %%
df_new.to_csv(os.path.join(path,'02 Data','Prepared Data', 'citi_clean.csv'))
